# %%
#set necessary libraries
import pandas as pd
import sqlalchemy
import sqlite3 as sq
from sqlalchemy import create_engine
import os

# %%
#we need to set our database credentials
user = 'claijymrfrcypu'
password = '161814975bead9a1ce22685f36e487dd360ee372bb2e8498bfd01e6e7eefbd51'
port = 5432
database = 'dfeggo6f6jkk7n'
host = 'ec2-54-225-72-238.compute-1.amazonaws.com'
url = f"postgres://{user}:{password}@{host}:{port}/{database}"
        
print(url)
# Out:
# postgres://claijymrfrcypu:161814975bead9a1ce22685f36e487dd360ee372bb2e8498bfd01e6e7eefbd51@ec2-54-225-72-238.compute-1.amazonaws.com:5432/dfeggo6f6jkk7n

# %%
#create engine
engine = sqlalchemy.create_engine(url)

#connect to our server

conn = engine.connect()

# %%
#we need to read our csv file
file = "Data/Combined_Data.csv"

# %%
#create a dataframe
df = pd.read_csv(file, index_col="Index")
df.head()
# Out:
#                  CountryName CountryCode          1960          1961  \
# Index
# GDP per capita         Aruba         ABW           NaN           NaN
# Life expectancy        Aruba         ABW     65.662000     66.074000
# Net migration          Aruba         ABW           NaN           NaN
# Population             Aruba         ABW  54211.000000  55438.000000
# GDP per capita   Afghanistan         AFG     59.777327     59.878153
#
#                          1962          1963          1964          1965  \
# Index
# GDP per capita            NaN           NaN           NaN           NaN
# Life expectancy     66.444000     66.787000     67.113000     67.435000
# Net migration    -4323.000000           NaN           NaN           NaN
# Population       56225.000000  56695.000000  57032.000000  57360.000000
# GDP per capita      58.492874     78.782758     82.208444    101.290471
#
#                          1966       1967      ...                 2008  \
# ...

# %%
# #create a different dataframe for Net migration
# df_migration = df["Index"] = "Net migration"
# df_migration.head()

# %%
#we need to upload our dataframe to Posgres SQL table in Heroku
df.to_sql(name="world_indices", con = engine, if_exists = 'replace')

# %%
# with engine.connect() as con:
#     con.execute('ALTER TABLE "world_indices" ADD PRIMARY KEY ("Index");')

# %%
#will also create sqlite file
conn2 = sq.connect(os.path.join('db','worldData.sqlite'))

# %%
# Create sql lite engine
engine2 = create_engine('sqlite:///db/worldData.sqlite', echo=False)

# %%
#add our df information to our sqlite file
df.to_sql('worldData', con=engine2, if_exists='replace')

# %%
# with engine2.connect() as con:
#     con.execute('ALTER TABLE worldData ADD PRIMARY KEY Index;')

# %%
#check our data
engine2.execute("SELECT * FROM worldData").fetchall()
# Out:
# [('GDP per capita', 'Aruba', 'ABW', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 6472.502029, 7885.796545, 9764.789979000001, 11392.45581, 12307.311740000001, 13496.00339, 14046.503999999999, 14936.82704, 16241.04632, 16439.356359999998, 16586.06844, 17927.74964, 19078.34319, 19356.203390000002, 20620.700630000003, 20669.03197, 20436.887130000003, 20833.761609999998, 22569.97499, 23300.03956, 24045.74942, 25835.64314, 27086.03985, 24630.93927, 23512.6026, 24984.27945, 24709.60226, 25018.30895, 25528.40378, 25796.38025, 25251.63968, 25655.10202),
# ...

# %%
#read our data
pd.read_sql_table(table_name='worldData', con=engine2)
# Out:
#                 Index           CountryName CountryCode          1960  \
# 0      GDP per capita                 Aruba         ABW           NaN
# 1     Life expectancy                 Aruba         ABW  6.566200e+01
# 2       Net migration                 Aruba         ABW           NaN
# 3          Population                 Aruba         ABW  5.421100e+04
# 4      GDP per capita           Afghanistan         AFG  5.977733e+01
# 5     Life expectancy           Afghanistan         AFG  3.229200e+01
# 6       Net migration           Afghanistan         AFG           NaN
# 7          Population           Afghanistan         AFG  8.996351e+06
# 8      GDP per capita                Angola         AGO           NaN
# 9     Life expectancy                Angola         AGO  3.325100e+01
# 10      Net migration                Angola         AGO           NaN
# 11         Population                Angola         AGO  5.643182e+06
# ...
